# %% [markdown]
# # EXAMEN DE PYTHON POUR DATA SCIENCE
#
# <table>
#   <tr>
#     <td>
#       <img src="upc.jpg" alt="Logo Université" width="150">
#     </td>
#     <td>
#       <h2>Université Protestante au Congo</h2>
#       <p><strong>Nom :</strong> Jenovic Kabongo Kalonji & Daniel Tshibangu Bukasa</p>
#       <p><strong>Doctorant :</strong> KITETA</p>
#       <p><strong>Assistant :</strong> Loadis KAKONI</p>
#       <p><strong>Date :</strong> Juillet 2025</p>
#     </td>
#   </tr>
# </table>
#
# ---
#
# ##  Sujet
#
# **Exploration approfondie de la bibliothèque Plotly et mise en œuvre pratique.**

# %% [markdown]
# #  1. Présentation de la bibliothèque Plotly
#
# ## 1.0. Historique de la bibliothèque Plotly
#
# Plotly est une bibliothèque de visualisation de données interactive développée par l’entreprise **Plotly Technologies Inc.**, fondée en **2012** à Montréal, au Canada, par Alex Johnson, Jack Parmer, Chris Parmer et Matthew Sundquist.
#
# À ses débuts, Plotly était principalement un outil en ligne permettant aux scientifiques et ingénieurs de partager facilement des visualisations de données interactives sur le web. Rapidement, l’équipe a développé des **bibliothèques open source** pour plusieurs langages, dont **Python, R, MATLAB et Julia**, afin de faciliter son intégration dans les environnements de travail des Data Scientists.
#
# En Python, Plotly est devenue populaire grâce à :
#
# - Sa capacité à produire des **graphiques interactifs directement dans les notebooks Jupyter**.
# - La sortie de **Plotly Express en 2019**, qui a simplifié la création de graphiques en fournissant une API haut niveau intuitive et rapide.
#
# Aujourd’hui, Plotly propose également **Dash**, un framework basé sur Plotly et Flask, permettant de créer des dashboards web interactifs professionnels sans écrire de code HTML/CSS/JavaScript.
#
# ---
#
# #### **Évolution de Plotly**
#
# - **2012** : Fondation de Plotly Technologies Inc.
# - **2013-2014** : Lancement de l’interface web Plotly.
# - **2015** : Publication de la bibliothèque Plotly pour Python.
# - **2017** : Lancement de **Dash** pour la création de dashboards interactifs.
# - **2019** : Sortie de **Plotly Express**, rendant la création de graphiques plus rapide et intuitive.
# - **Aujourd’hui** : Plotly est utilisée par de grandes entreprises, chercheurs et data scientists pour la visualisation interactive et le développement d’applications analytiques.
#
# ---
#
# En résumé, **Plotly est une bibliothèque moderne et puissante, née d’une entreprise innovante spécialisée dans la visualisation interactive**, qui continue d’évoluer pour répondre aux besoins croissants de la Data Science et de la Business Intelligence.
#
#
# ## 1.1 Objectifs de Plotly
#
# Plotly est une **bibliothèque de visualisation de données interactive** pour Python. Son objectif principal est de permettre aux data scientists, analystes et ingénieurs d’explorer et de présenter leurs données sous forme de graphiques dynamiques, professionnels et facilement interprétables.
#
#  **Ses objectifs principaux sont :**
#
# - Créer des **graphes interactifs** directement intégrables dans Jupyter Notebook, sites web ou dashboards.
# - Fournir des **visualisations de qualité publication** avec une esthétique soignée.
# - Faciliter l’**exploration des données complexes** grâce à l’interactivité (zoom, hover, sélection).
# - Permettre la création d’**applications analytiques interactives** à grande échelle avec Dash (framework basé sur Plotly).
#
# ---
#
# ## 1.2 Architecture générale de Plotly
#
# Plotly est organisé en plusieurs composants principaux :
#
# 1. **plotly.graph_objects**
#    - Composants graphiques bas niveau permettant un contrôle total sur les éléments des graphes.
#    - Exemple : `go.Figure()`, `go.Scatter()`, `go.Bar()`
#
# 2. **plotly.express**
#    - API haut niveau et simplifiée pour créer rapidement des graphiques courants en une seule ligne de code.
#    - Exemple : `px.scatter()`, `px.bar()`, `px.line()`
#
# 3. **Dash**
#    - Framework web basé sur Flask, React.js et Plotly, permettant de construire des **dashboards interactifs complets**.
#
# 🔧 **Fonctionnement interne (simplifié) :**
#
# - Plotly génère des objets graphiques Python.
# - Ceux-ci sont convertis en **code HTML + Javascript (Plotly.js)**.
# - Ce code s’affiche dans un notebook Jupyter ou un navigateur, rendant le graphique interactif.
#
# ---
#
# ## 1.3 Modules importants de Plotly
#
# |  **Module** |  **Description** |
# | --- | --- |
# | **plotly.express (px)** | Interface haut niveau pour créer des graphiques rapidement (scatter, bar, line, box, choropleth). |
# | **plotly.graph_objects (go)** | Interface bas niveau pour un contrôle complet des graphes et mise en page personnalisée. |
# | **plotly.io** | Fonctions d’entrée/sortie, notamment pour exporter les graphiques en PNG, JPEG ou HTML. |
# | **dash** | Framework basé sur Plotly pour créer des applications web interactives (non couvert en détail ici). |
#
# ---
#
#  **Résumé**
#
# Plotly est ainsi une **bibliothèque complète et flexible** pour toutes les visualisations interactives, allant de simples graphes exploratoires à des dashboards analytiques professionnels.

# %% [markdown]
# #  2. Analyse détaillée des méthodes, classes et modules utilisés
#
# Dans cette section, nous analysons en détail les **modules principaux de Plotly**, leurs méthodes clés et leurs rôles dans le traitement, l’analyse et la visualisation des données.
#
# ---
#
# ## 2.1 Modules principaux
#
# ###  plotly.express (px)
#
#  **Description :**
#
# - `plotly.express` est le **module haut niveau** de Plotly.
# - Il permet de créer rapidement des graphiques courants (scatter plot, bar chart, line plot, box plot, choropleth map, etc.) en **une seule ligne de code**.
#
#  **Utilisation principale :**
#
# - Idéal pour l’**exploration rapide des données**.
# - Génère automatiquement la figure et affiche un graphique interactif.
#
#  **Exemple pratique :**

# %%
import plotly.express as px

# Charger un dataset exemple
df = px.data.gapminder()

# Filtrer l'année 2007
df_2007 = df[df["year"] == 2007]

# Créer un scatter plot interactif
fig = px.scatter(
    data_frame=df_2007,
    x="gdpPercap",
    y="lifeExp",
    color="continent",
    size="pop",
    hover_name="country",
    log_x=True,
    size_max=60,
    title="GDP per Capita vs Life Expectancy (2007)"
)

fig.show()

# %% [markdown]
#  ## plotly.graph_objects (go)
#  Description :
#
# plotly.graph_objects est le module bas niveau de Plotly.
#
# Il donne un contrôle total sur la construction du graphique, chaque élément peut être modifié individuellement.
#
#  Utilisation principale :
#
# Créer des visualisations hautement personnalisées.
#
# Ajouter plusieurs traces (courbes, barres, surfaces) et modifier le layout en détail.
#
#  Exemple pratique :

# %%
import plotly.graph_objects as go

# Créer une figure vide
fig = go.Figure()

# Ajouter une trace scatter
fig.add_trace(go.Scatter(
    x=df_2007["gdpPercap"],
    y=df_2007["lifeExp"],
    mode="markers",
    marker=dict(size=10, color="red"),
    text=df_2007["country"]
))

# Personnaliser le layout
fig.update_layout(
    title="GDP per Capita vs Life Expectancy (2007) - graph_objects",
    xaxis_title="GDP per Capita",
    yaxis_title="Life Expectancy",
    template="plotly_white"
)

fig.show()

# %% [markdown]
#  Rôle : construire des graphiques personnalisés et multi-traces adaptés aux présentations professionnelles et dashboards interactifs.

# %% [markdown]
# ## 2.2 Méthodes et fonctions clés

# %% [markdown]
# #### fig.show()
#  Description :
#
# Méthode utilisée pour afficher la figure générée dans le notebook ou le navigateur.
#
#  Exemple :
#
# ```python
# fig.show()

# %% [markdown]
# #### fig.update_layout()

# %% [markdown]
#  Description :
#
# Méthode permettant de personnaliser l’apparence générale du graphique, comme :
#
# Titre,
# Noms des axes,
# Thème,
# Légende,
# Marges et tailles.
#
#  Exemple :
# ```python
# fig.update_layout(
#     title="Titre du graphique",
#     xaxis_title="Axe des X",
#     yaxis_title="Axe des Y",
#     legend_title="Légende",
#     template="plotly_dark"
# )

# %% [markdown]
#  Rôle : améliore l’esthétique et la lisibilité du graphique.

# %% [markdown]
# #### fig.add_trace()

# %% [markdown]
#  Description :
#
# Méthode utilisée avec graph_objects pour ajouter une nouvelle trace (courbe, barres, markers, etc.) à la figure.
#
#  Exemple :
# ```python
# fig.add_trace(go.Bar(
#     x=["A", "B", "C"],
#     y=[10, 20, 15],
#     name="Example Bar"
# ))

# %% [markdown]
# 🎯 Rôle : permet de superposer plusieurs séries de données sur un même graphique.

# %% [markdown]
# ## 2.3 Récapitulatif des modules et méthodes

# %% [markdown]
# |   **Module / Méthode** |  **Rôle** |
# | --- | --- |
# | **plotly.express** | Créer rapidement des graphiques courants avec une API haut niveau. |
# | **plotly.graph_objects** | Construire des graphiques personnalisés et complexes avec un contrôle total. |
# | **fig.show()** | Afficher le graphique généré. |
# | **fig.update_layout()** | Personnaliser l’apparence et le layout du graphique. |
# | **fig.add_trace()** | Ajouter une nouvelle trace à la figure (scatter, bar, etc.). |
#
# ---
#
#  **Conclusion**
#
# Ces modules et méthodes sont **indispensables pour toute analyse et présentation de données interactives**. Ils permettent de passer d’une exploration rapide (**plotly.express**) à une présentation professionnelle et personnalisée (**plotly.graph_objects**), adaptée aux projets Data Science et dashboards interactifs.

# %% [markdown]
# ### 2.4 Types de graphiques dans Plotly
#
# Plotly permet d’afficher une large variété de visualisations interactives, notamment :
#
# #### 1. Graphiques statistiques classiques
#
# - **Scatter plot (Nuage de points)**
#   Pour visualiser la relation entre deux variables.
#
# - **Line plot (Graphique linéaire)**
#   Pour suivre l’évolution d’une variable dans le temps.
#
# - **Bar plot (Histogramme ou diagramme en barres)**
#   Pour comparer des valeurs catégorielles.
#
# - **Box plot (Boîte à moustaches)**
#   Pour résumer la distribution d’une variable (médiane, quartiles, outliers).
#
# - **Violin plot (Violons)**
#   Alternative au boxplot, montrant la densité des données.
#
# - **Histogram plot (Histogramme de fréquence)**
#   Pour visualiser la distribution des valeurs d’une variable numérique.
#
# ---
#
# #### 2. Graphiques catégoriels
#
# - **Pie chart (Diagramme circulaire)**
#   Pour représenter la proportion de chaque catégorie.
#
# - **Sunburst chart (Soleil hiérarchique)**
#   Pour visualiser des données hiérarchiques sous forme circulaire.
#
# - **Treemap (Arbre de rectangles)**
#   Pour représenter la hiérarchie sous forme de rectangles proportionnels.
#
# ---
#
# #### 3. Graphiques multivariés et avancés
#
# - **Bubble chart (Bulles)**
#   Extension du scatter plot avec une 3ᵉ dimension (taille des points).
#
# - **Heatmap (Carte de chaleur)**
#   Pour visualiser des matrices de valeurs (ex : corrélations).
#
# - **Density heatmap (Densité en couleurs)**
#   Pour représenter la densité de points dans l’espace.
#
# ---
#
# #### 4. Graphiques temporels et financiers
#
# - **Candlestick chart (Bougies japonaises)**
#   Pour analyser les prix en bourse (open, high, low, close).
#
# - **OHLC chart**
#   Similaire au candlestick mais sous forme de barres.
#
# ---
#
# #### 5. Graphiques géographiques
#
# - **Choropleth map (Carte choroplèthe)**
#   Pour représenter des données sur une carte géographique par régions.
#
# - **Scatter geo plot**
#   Pour afficher des points géolocalisés sur une carte.
#
# - **Mapbox map**
#   Pour des visualisations géographiques avancées et interactives.
#
# ---
#
# #### 6. Graphiques 3D
#
# - **3D scatter plot (Nuage de points 3D)**
#
# - **3D surface plot (Surface 3D)**
#
# - **3D line plot (Lignes 3D)**
#
# ---
#
# #### 7. Graphiques spéciaux
#
# - **Polar plot (Graphiques polaires)**
#
# - **Funnel chart (Entonnoir)**
#
# - **Gauge chart (Jauge)**
#
# - **Sankey diagram (Flux Sankey)**
#
# - **Parallel coordinates plot (Coordonnées parallèles)**

# %% [markdown]
# # 2.4.1 exemple de chaque type principal de graphique avec Plotly

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Graphiques statistiques classiques
# Scatter plot

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", title="Scatter Plot: Iris Dataset")
fig.show()

# %% [markdown]
# ### 2. Graphiques catégoriels
# Pie chart

# %%
df = px.data.tips()
fig = px.pie(df, names="day", values="total_bill", title="Pie Chart: Total Bill by Day")
fig.show()

# %% [markdown]
# ### 3. Graphiques multivariés et avancés
# Bubble chart

# %%
df = px.data.gapminder().query("year==2007")
fig = px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", color="continent", hover_name="country", log_x=True, size_max=60, title="Bubble Chart: GDP per Capita vs Life Expectancy")
fig.show()

# %% [markdown]
# ### 4. Graphiques temporels et financiers
# Scatter geo plot

# %%
df = px.data.gapminder().query("year==2007")
fig = px.scatter_geo(df, locations="iso_alpha", color="continent", size="pop", hover_name="country", title="Scatter Geo Plot: Population by Country")
fig.show()

# %% [markdown]
# ### 6. Graphiques 3D
# 3D scatter plot

# %%
df = px.data.iris()
fig = px.scatter_3d(df, x="sepal_length", y="sepal_width", z="petal_length", color="species", title="3D Scatter Plot: Iris")
fig.show()

# %% [markdown]
# ### 7. Graphiques spéciaux
# Polar plot

# %%
r = [1, 2, 3, 4, 5]
theta = [0, 45, 90, 135, 180]
fig = px.line_polar(r=r, theta=theta, title="Polar Plot Example")
fig.show()

# %% [markdown]
# #  Partie 3 : Mise en œuvre pratique – Analyse comparative de 10 indices boursiers mondiaux
#
# ##  Objectif
#
# Comparer l’évolution de **10 indices boursiers mondiaux** (Dow Jones, Nasdaq, CAC 40, DAX, FTSE 100, Nikkei 225, Shanghai Composite, Sensex, S&P 500, Euro Stoxx 50) de 2020 à 2024 grâce à **Plotly**.
#
# ---
#
# ##  3.1 Installation et importation des bibliothèques

# %%
# Installer yfinance si nécessaire
# !pip install yfinance

# %%
# Importer les bibliothèques
import yfinance as yf
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## 3.2 Téléchargement des données

# %%
# Liste des indices et leurs tickers Yahoo Finance
indices = {
    "^DJI": "Dow Jones",
    "^IXIC": "Nasdaq",
    "^GSPC": "S&P 500",
    "^FTSE": "FTSE 100",
    "^GDAXI": "DAX",
    "^FCHI": "CAC 40",
    "^N225": "Nikkei 225",
    "000001.SS": "Shanghai Composite",
    "^BSESN": "Sensex",
    "^STOXX50E": "Euro Stoxx 50"
}

# Télécharger les données de 2020 à 2024
data = yf.download(list(indices.keys()), start="2020-01-01", end="2024-12-31")["Close"]

# Renommer les colonnes avec les noms clairs
data.rename(columns=indices, inplace=True)

# Aperçu des données
data.head()
# Out:
# C:\Users\congo\AppData\Local\Temp\ipykernel_2676\1079058952.py:16: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  10 of 10 completed
# Ticker      Shanghai Composite        Sensex     Dow Jones       CAC 40  \
# Date
# 2020-01-02         3085.197998  41626.640625  28868.800781  6041.500000
# 2020-01-03         3083.785889  41464.609375  28634.880859  6044.160156
# 2020-01-06         3083.407959  40676.628906  28703.380859  6013.589844
# 2020-01-07         3104.802002  40869.468750  28583.679688  6012.350098
# 2020-01-08         3066.893066  40817.738281  28745.089844  6031.000000
#
# Ticker         FTSE 100           DAX      S&P 500       Nasdaq    Nikkei 225  \
# Date
# 2020-01-02  7604.299805  13385.929688  3257.850098  9092.190430           NaN
# 2020-01-03  7622.399902  13219.139648  3234.850098  9020.769531           NaN
# ...

# %% [markdown]
# ## 3.3 Préparation des données pour Plotly

# %%
# Réinitialiser l'index
df = data.reset_index()

# Transformer en format long
df_melted = df.melt(id_vars=["Date"], var_name="Indice", value_name="Close")

# Aperçu des données transformées
df_melted.head()
# Out:
#         Date              Indice        Close
# 0 2020-01-02  Shanghai Composite  3085.197998
# 1 2020-01-03  Shanghai Composite  3083.785889
# 2 2020-01-06  Shanghai Composite  3083.407959
# 3 2020-01-07  Shanghai Composite  3104.802002
# 4 2020-01-08  Shanghai Composite  3066.893066

# %% [markdown]
# ## 3.4 Visualisation interactive comparative

# %%
# Créer un graphique line plot interactif
fig = px.line(
    df_melted,
    x="Date",
    y="Close",
    color="Indice",
    title=" Évolution des principaux indices boursiers (2020-2024)",
    labels={"Close":"Cours de clôture ($)", "Date":"Date"}
)

fig.show()

# %%
# Calcul du rendement quotidien et annualisé
returns = data.pct_change()
annual_return = returns.mean() * 252
volatility = returns.std() * (252 ** 0.5)

# Créer un DataFrame récapitulatif
risk_return = pd.DataFrame({
    "Annual Return (%)": annual_return * 100,
    "Volatility (%)": volatility * 100
})

risk_return.reset_index(inplace=True)
risk_return.rename(columns={"index":"Indice"}, inplace=True)

# Visualisation Risk vs Return
fig = px.scatter(
    risk_return,
    x="Volatility (%)",
    y="Annual Return (%)",
    text="Ticker",
    title="⚖️ Risk vs Return des indices boursiers (2020-2024)"
)
fig.show()
# Out:
# C:\Users\congo\AppData\Local\Temp\ipykernel_2676\616246686.py:2: FutureWarning:
#
# The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.

# %% [markdown]
# #  Partie 4 : Réflexion critique sur Plotly
#
# ##  **Objectifs de la réflexion**
#
# Analyser de manière critique :
#
# - Les **forces** de Plotly
# - Ses **limites techniques et pratiques**
# - Ses **cas d’utilisation idéaux**
# - Comparaisons avec d’autres bibliothèques si nécessaire
#
# ---
#
# ##  **4.1 Forces de Plotly**
#
# |  **Atout** |  **Explication** |
# |---|---|
# | **Visualisations interactives** | Permet d’explorer les données en détail (hover, zoom, filtre) sans écrire beaucoup de code complexe. |
# | **Large choix de graphiques** | Line, bar, scatter, candlestick, choroplèthe, sunburst, heatmap, boxplot, etc. |
# | **Esthétique professionnelle** | Graphiques immédiatement présentables pour un rapport, un dashboard ou une présentation. |
# | **Facilité d’intégration** | Compatible avec Jupyter, Dash (pour des dashboards web interactifs) et frameworks web. |
# | **Personnalisation complète** | Avec `plotly.graph_objects`, chaque élément du graphique peut être configuré finement. |
#
# ---
#
# ##  **4.2 Limites de Plotly**
#
# |  **Limite** |  **Détails** |
# |---|---|
# | **Courbe d’apprentissage** | L’utilisation avancée (e.g. graph_objects) nécessite plus de pratique que des bibliothèques comme Seaborn ou Matplotlib. |
# | **Performances sur gros datasets** | Moins performant sur des millions de points sans techniques d’optimisation ou d’agrégation. |
# | **Taille des fichiers HTML** | Les graphiques Plotly exportés en HTML peuvent devenir lourds si beaucoup d’interactivité est intégrée. |
# | **Moins adapté aux publications scientifiques statiques** | Matplotlib reste plus standardisé pour des publications PDF ou LaTeX sans interactivité. |
#
# ---
#
# ##  **4.3 Cas d’utilisation idéaux de Plotly**
#
#  Visualisations interactives pour :
#
# - Analyses exploratoires interactives (Data Analysis / Business Intelligence)
# - Dashboards dynamiques (avec Plotly Dash)
# - Présentations exécutives et rapports financiers
# - Visualisation de séries temporelles complexes (bourses, IoT, data logs)
# - Projets Data Science nécessitant une **communication visuelle efficace et esthétique**
#
# ---
#
# ##  **4.4 Comparaison rapide avec d’autres bibliothèques**
#
# |  **Librairie** |  **Points forts** |  **Points faibles** |
# |---|---|---|
# | **Matplotlib** | Personnalisation extrême, standard en recherche scientifique. | Moins interactif, style par défaut simple. |
# | **Seaborn** | Visualisations statistiques rapides et esthétiques. | Peu d’interactivité native. |
# | **Plotly** | Interactivité complète, esthétique professionnelle, dashboards. | Plus lourd pour des visualisations basiques. |
# | **Bokeh** | Très bon pour dashboards et web. | Moins simple que Plotly pour un notebook rapide. |
#
# ---
#
# ##  **4.5 Conclusion critique**
#
# Plotly est une bibliothèque **puissante, interactive et esthétique**, idéale pour :
#
#  L’exploration rapide (plotly.express)
#  Les présentations interactives professionnelles
#  La création de dashboards dynamiques (Plotly Dash)
#
# Cependant, pour des publications scientifiques statiques ou l’analyse de datasets massifs (big data), il est recommandé de :
#
# - **Compléter Plotly avec Dask, Spark ou Datashader** pour gérer le volume de données
# - Utiliser Matplotlib pour des rendus vectoriels optimisés sans interactivité.
#
# ---
